# %% [markdown]
# **1. Change the directory to the google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/scCL/main_semi_test_new')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/scCL/main_semi_test_new

# %% [markdown]
# **2. Install the packages for scCL**

# %%
# !pip install torch torchvision torchaudio
# !pip install pytorch-lightning
# !pip install anndata
# !pip install lightning-bolts
# !pip install scanpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 832.4/832.4 kB 8.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 32.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 kB 2.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.2/58.2 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 65.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.5/53.5 kB 7.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 18.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.5.5
#     Uninstalling pytorch-lightning-2.5.5:
#       Successfully uninstalled pytorch-lightning-2.5.5
# ...

# %% [markdown]
# **3. scCL manual**

# %%
# !python LCL_Main_Semi.py --help
# Out:
# /usr/local/lib/python3.11/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.11/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
# ...

# %% [markdown]
# **4. Run scCL**

# %%
# !python LCL_Main_Semi.py --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/cell_tag_cell_tag_multi/cellTag_test_multi_Seurat_clone_id.h5ad" \
                                              --testFilePath "/content/drive/MyDrive/Colab Notebooks/data/cell_tag_cell_tag_multi/cellTag_train_tag_Seurat.h5ad" \
                                              --batch_size 250 \
                                              --size_factor 0.02 \
                                              --unlabeled_per_batch 50 \
                                              --lambda_penalty 0.05 \
                                              --temperature 0.5 \
                                              --max_epoch 220\
                                              --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty" \
                                              --train_test 1
# Out:
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
# ...

# %% [markdown]
# **5. extract the features**

# %%
# !python feature_extraction.py --help
# Out:
# usage: feature_extraction.py [-h] --inputFilePath INPUTFILEPATH
#                              [--batch_size BATCH_SIZE] --output_dir OUTPUT_DIR
#                              --resume_from_checkpoint RESUME_FROM_CHECKPOINT
#                              [--hidden_dims HIDDEN_DIMS]
#                              [--embedding_size EMBEDDING_SIZE]
#
# Extract base-encoder features from a trained LCL model
#
# options:
#   -h, --help            show this help message and exit
#   --inputFilePath INPUTFILEPATH
#                         Path to AnnData (.h5ad) for feature extraction
#   --batch_size BATCH_SIZE
#                         Batch size for featurizing all cells
#   --output_dir OUTPUT_DIR
#                         Directory to save extracted feature .npy
#   --resume_from_checkpoint RESUME_FROM_CHECKPOINT
#                         Path to trained .ckpt file
#   --hidden_dims HIDDEN_DIMS
#                         Comma-separated hidden dimensions for encoder
# ...

# %%
# !python feature_extraction.py --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/cell_tag_cell_tag_multi/cellTag_train_tag_Seurat.h5ad" \
    --batch_size 250 \
    --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty" \
    --resume_from_checkpoint "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt"
# Out:
# Detected input_dim = 1960
# Loaded checkpoint from /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt
# Featurizing 6534 cells in 27 batches
# Extracted features shape: (6534, 64)
# Saved features to /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/scBaseEncoderFeat_Z_bs250_tau0.5.npy
# Done in 0.01 minutes

# %%
# !python project_head_extraction.py \
  --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/cell_tag_cell_tag_multi/cellTag_train_tag_Seurat.h5ad" \
  --batch_size 250 \
  --out_file_name 'test_proj_embed.npy' \
  --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty" \
  --resume_from_checkpoint "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt"
# Out:
# --------------------- PROJECTION EMBEDDING EXTRACTION ---------------------
# inputFilePath: /content/drive/MyDrive/Colab Notebooks/data/cell_tag_cell_tag_multi/cellTag_train_tag_Seurat.h5ad
# resume_from_checkpoint: /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt
# inferred input_dim: 1960
# hidden_dims: [1024, 256, 64]
# embedding_size: 32
# batch_size (inference): 250
# [OK] Loaded checkpoint: /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt
# [SAVED] /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/test_proj_embed.npy  (shape=(6534, 32))
# ...

# %%
# !python project_head_extraction.py \
  --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/cell_tag_cell_tag_multi/cellTag_test_multi_Seurat_clone_id.h5ad" \
  --batch_size 250 \
  --out_file_name 'train_proj_embed.npy' \
  --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty" \
  --resume_from_checkpoint "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt"
# Out:
# --------------------- PROJECTION EMBEDDING EXTRACTION ---------------------
# inputFilePath: /content/drive/MyDrive/Colab Notebooks/data/cell_tag_cell_tag_multi/cellTag_test_multi_Seurat_clone_id.h5ad
# resume_from_checkpoint: /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt
# inferred input_dim: 1960
# hidden_dims: [1024, 256, 64]
# embedding_size: 32
# batch_size (inference): 250
# [OK] Loaded checkpoint: /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt
# [SAVED] /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/cell_tag_cell_tag_multi/feat_celltagMulti_lambda005_unlab50_bs250_testAsPenalty/train_proj_embed.npy  (shape=(22238, 32))
# ...
