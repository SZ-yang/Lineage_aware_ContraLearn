# %% [markdown]
# **1. Change the directory to the google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/scCL/main_semi_test_new')
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/scCL/main_semi_test_new

# %% [markdown]
# **2. Install the packages for scCL**

# %%
# !pip install torch torchvision torchaudio
# !pip install pytorch-lightning
# !pip install anndata
# !pip install lightning-bolts
# !pip install scanpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 20.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 65.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 174.2/174.2 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.6/58.6 kB 6.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 284.1/284.1 kB 17.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 113.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 13.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 37.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.6.0
#     Uninstalling pytorch-lightning-2.6.0:
#       Successfully uninstalled pytorch-lightning-2.6.0
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 40.9 MB/s eta 0:00:00
# ...

# %% [markdown]
# **3. scCL manual**

# %%
# !python LCL_Main_Semi.py --help
# Out:
# /usr/local/lib/python3.12/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# /usr/local/lib/python3.12/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
# ...

# %% [markdown]
# **4. Run scCL**

# %%
# !python LCL_Main_Semi.py --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/Larry_200_train.h5ad" \
                                              --testFilePath "/content/drive/MyDrive/Colab Notebooks/data/Larry_200_test.h5ad" \
                                              --batch_size 150 \
                                              --size_factor 0.5 \
                                              --unlabeled_per_batch 15 \
                                              --lambda_penalty 0.01 \
                                              --temperature 0.5 \
                                              --max_epoch 220\
                                              --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty" \
                                              --train_test 1
# Out:
# /usr/local/lib/python3.11/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.11/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# ...

# %% [markdown]
# **5. extract the features**

# %%
# !python feature_extraction.py --help
# Out:
# usage: feature_extraction.py [-h] --inputFilePath INPUTFILEPATH
#                              [--batch_size BATCH_SIZE] --output_dir OUTPUT_DIR
#                              --resume_from_checkpoint RESUME_FROM_CHECKPOINT
#                              [--hidden_dims HIDDEN_DIMS]
#                              [--embedding_size EMBEDDING_SIZE]
#
# Extract base-encoder features from a trained LCL model
#
# options:
#   -h, --help            show this help message and exit
#   --inputFilePath INPUTFILEPATH
#                         Path to AnnData (.h5ad) for feature extraction
#   --batch_size BATCH_SIZE
#                         Batch size for featurizing all cells
#   --output_dir OUTPUT_DIR
#                         Directory to save extracted feature .npy
#   --resume_from_checkpoint RESUME_FROM_CHECKPOINT
#                         Path to trained .ckpt file
#   --hidden_dims HIDDEN_DIMS
#                         Comma-separated hidden dimensions for encoder
# ...

# %%
# !python feature_extraction.py \
  --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/Larry_200_train.h5ad" \
  --batch_size 150 \
  --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty" \
  --resume_from_checkpoint "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt" \
  --out_file_name "train_base_embed.npy"
# Out:
# Detected input_dim = 2000, n_obs = 10148
# === STATE_DICT LOAD REPORT (bare BaseEncoder_ProjHead_MLP) ===
# missing: 0
# unexpected: 0
# missing examples: []
# unexpected examples: []
# ...
# Extracted base features shape: (10148, 64)
# [SAVED] /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/train_base_embed.npy
# [SAVED] /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/cell_ids_bs150.txt
# Done in 0.01 minutes

# %%
# !python feature_extraction.py \
  --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/Larry_200_test.h5ad" \
  --batch_size 150 \
  --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty" \
  --resume_from_checkpoint "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt" \
  --out_file_name "test_base_embed.npy"
# Out:
# Detected input_dim = 2000, n_obs = 1225
# === STATE_DICT LOAD REPORT (bare BaseEncoder_ProjHead_MLP) ===
# missing: 0
# unexpected: 0
# missing examples: []
# unexpected examples: []
# ...
# Extracted base features shape: (1225, 64)
# [SAVED] /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/test_base_embed.npy
# [SAVED] /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/cell_ids_bs150.txt
# Done in 0.02 minutes

# %%
# !python project_head_extraction.py \
  --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/Larry_200_train.h5ad" \
  --batch_size 150 \
  --out_file_name 'train_proj_embed.npy' \
  --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty" \
  --resume_from_checkpoint "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt"
# Out:
# --------------------- PROJECTION EMBEDDING EXTRACTION ---------------------
# inputFilePath: /content/drive/MyDrive/Colab Notebooks/data/Larry_200_train.h5ad
# resume_from_checkpoint: /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt
# inferred input_dim: 2000
# hidden_dims: [1024, 256, 64]
# embedding_size: 32
# batch_size (inference): 150
# === STATE_DICT LOAD REPORT ===
# missing: 0
# unexpected: 0
# missing examples: []
# unexpected examples: []
# ...
# [OK] Loaded checkpoint: /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt
# [SAVED] /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/train_proj_embed.npy  (shape=(10148, 32))
# ...

# %%
# !python project_head_extraction.py \
  --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/Larry_200_test.h5ad" \
  --batch_size 150 \
  --out_file_name 'test_proj_embed.npy' \
  --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty" \
  --resume_from_checkpoint "/content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt"
# Out:
# --------------------- PROJECTION EMBEDDING EXTRACTION ---------------------
# inputFilePath: /content/drive/MyDrive/Colab Notebooks/data/Larry_200_test.h5ad
# resume_from_checkpoint: /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt
# inferred input_dim: 2000
# hidden_dims: [1024, 256, 64]
# embedding_size: 32
# batch_size (inference): 150
# === STATE_DICT LOAD REPORT ===
# missing: 0
# unexpected: 0
# missing examples: []
# unexpected examples: []
# ...
# [OK] Loaded checkpoint: /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/saved_models/scContrastiveLearn_last.ckpt
# [SAVED] /content/drive/MyDrive/Colab Notebooks/scCL/output/LCL_2025/Larry_top200/lambda0.01_unlab15_bs150_testAsPenalty/test_proj_embed.npy  (shape=(1225, 32))
# ...
