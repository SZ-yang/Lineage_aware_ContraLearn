# %% [markdown]
# **1. Change the directory to the google drive**

# %%
from google.colab import drive
drive.mount('/content/drive')
import os
os.chdir('/content/drive/My Drive/Colab Notebooks/scCL/main')
# Out:
# Mounted at /content/drive

# %%
# !pwd
# Out:
# /content/drive/My Drive/Colab Notebooks/scCL/main

# %% [markdown]
# **2. Install the packages for scCL**

# %%
# !pip install torch torchvision torchaudio
# !pip install pytorch-lightning
# !pip install anndata
# !pip install lightning-bolts
# !pip install scanpy
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.2/815.2 kB 19.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 869.2/869.2 kB 47.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.0/129.0 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.5/49.5 kB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.8/300.8 kB 9.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 829.5/829.5 kB 42.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pytorch-lightning
#     Found existing installation: pytorch-lightning 2.4.0
#     Uninstalling pytorch-lightning-2.4.0:
#       Successfully uninstalled pytorch-lightning-2.4.0
# ...
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 36.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.9/56.9 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 10.4 MB/s eta 0:00:00
# ...

# %% [markdown]
# **3. scCL manual**

# %%
# !python scContrastiveLearning_Main_709_ckpt_epoch.py --help
# Out:
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/__init__.py:11: FutureWarning: In the future `np.bool` will be defined as the corresponding NumPy scalar.
#   if not hasattr(numpy, tp_name):
# /usr/local/lib/python3.10/dist-packages/pl_bolts/models/self_supervised/amdim/amdim_module.py:34: UnderReviewWarning: The feature generate_power_seq is currently marked under review. The compatibility with other Lightning projects is not guaranteed and API may change at any time. The API and functionality may change without warning in future releases. More details: https://lightning-bolts.readthedocs.io/en/latest/stability.html
#   "lr_options": generate_power_seq(LEARNING_RATE_CIFAR, 11),
# ...

# %% [markdown]
# **4. Run scCL**

# %%
# !python scContrastiveLearning_Main_709_ckpt_epoch.py --inputFilePath "/content/drive/MyDrive/Colab Notebooks/data/Larry_Simulation_05_final_final.h5ad" \
                                              --batch_size 100 \
                                              --size_factor 0.4 \
                                              --temperature 0.5 \
                                              --max_epoch 220\
                                              --output_dir "/content/drive/MyDrive/Colab Notebooks/scCL/output/feat_simulation_beta05_final_final" \
                                              --train_test 1
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch 11:  93% 8460/9064 [01:25<00:06, 98.48it/s, loss=3.4, v_num=20, val_loss=3.430, avg_val_loss=3.430, train_loss=3.400]
# Epoch 11:  94% 8480/9064 [01:26<00:05, 98.59it/s, loss=3.4, v_num=20, val_loss=3.430, avg_val_loss=3.430, train_loss=3.400]
# Epoch 11:  94% 8500/9064 [01:26<00:05, 98.70it/s, loss=3.4, v_num=20, val_loss=3.430, avg_val_loss=3.430, train_loss=3.400]
# Epoch 11:  94% 8520/9064 [01:26<00:05, 98.82it/s, loss=3.4, v_num=20, val_loss=3.430, avg_val_loss=3.430, train_loss=3.400]
# Epoch 11:  94% 8540/9064 [01:26<00:05, 98.93it/s, loss=3.4, v_num=20, val_loss=3.430, avg_val_loss=3.430, train_loss=3.400]
# Epoch 11:  94% 8560/9064 [01:26<00:05, 99.05it/s, loss=3.4, v_num=20, val_loss=3.430, avg_val_loss=3.430, train_loss=3.400]
# Epoch 11:  95% 8580/9064 [01:26<00:04, 99.17it/s, loss=3.4, v_num=20, val_loss=3.430, avg_val_loss=3.430, train_loss=3.400]
# ...

# %%
from sklearn.metrics import calinski_harabasz_score
import anndata as ad
import numpy as np

# %%
adata = ad.read_h5ad('/content/drive/MyDrive/Colab Notebooks/data/Larry_Simulation_05_final_final.h5ad')
lineage_label = adata.obs["clone_id"].to_numpy()
x = np.load("/content/drive/MyDrive/Colab Notebooks/scCL/output/feat_simulation_beta05_final_final/scBaseEncoderFeat_Z_bs100_tau0.5.npy")

score = calinski_harabasz_score(x, lineage_label)
score
# Out:
# 9232.243120653564
